# %%
import pandas as pd
import os

# %%
DERS_LISTESI_PATH = r'Ders Listesi.xlsx'
OGRENCI_LISTESI_PATH = r'ogrenci_listesi.xlsx'

# %%
def oku_ders_listesi(path: str, sheet_name: str = "Ders Listesi") -> pd.DataFrame:
    df = pd.read_excel(path, sheet_name=sheet_name, header=None)

    sinif_rows = df[df[0].astype(str).str.contains("Sınıf", case=False, na=False)].reset_index()

    rows = []
    for i in range(len(sinif_rows)):
        start = sinif_rows.loc[i, "index"] + 2 
        end = sinif_rows.loc[i+1, "index"] if i+1 < len(sinif_rows) else len(df)
        sinif = df.loc[sinif_rows.loc[i, "index"], 0]

        block = df.iloc[start:end, :3].copy()
        block.columns = ["DERS KODU", "DERSİN ADI", "DERSİ VEREN ÖĞR. ELEMANI"]
        secmeli_mask = block["DERS KODU"].astype(str).str.contains("Seçimlik|Seçmeli", case=False, na=False)

        if secmeli_mask.any():
            secmeli_index = secmeli_mask.idxmax()
            block = block.drop(secmeli_index)
            
            block["Seçmeli mi?"] = False
            block.loc[secmeli_index+1:, "Seçmeli mi?"] = True
        else:
            block["Seçmeli mi?"] = False

        block["SINIF"] = sinif
        rows.append(block)

    final_df = pd.concat(rows, ignore_index=True)
    
    final_df = final_df[~final_df["DERS KODU"].isin(['DERS KODU', 'DERSİN ADI', 'DERSİ VEREN ÖĞR. ELEMANI'])]
    
    final_df.to_excel("processed_ders_listesi.xlsx", index=False)
    
    return final_df

# %%
ders_list_df = oku_ders_listesi(DERS_LISTESI_PATH)
print(ders_list_df)
# Out:
#    DERS KODU                                     DERSİN ADI  \
# 0     AIT109           Atatürk İlkeleri ve İnkılap Tarihi I
# 1     TDB107                                    Türk Dili I
# 2     YDB117                                    İngilizce I
# 3     FEF111                                        Fizik I
# 4     FEF113                                   Lineer Cebir
# 5     FEF115                                    Matematik I
# 6     BLM101                      Bilgisayar Laboratuvarı I
# 7     BLM103                Bilgisayar Mühendisliğine Giriş
# 8     BLM105                                 Programlama I
# 9     FEF203                        Diferansiyel Denklemler
# 10    MUH201                    Nesneye Yönelik Programlama
# 11    BLM207                 Veri Yapıları ve Algoritmaları
# 12    BLM209                  Programlama Laboratuvarı - I
# 13    BLM211               Mantıksal Tasarım ve Uygulamalar
# 14    BLM205                                Ayrık Matematik
# 15    BLM213                                         Staj I
# 16    MUH301                              Sayısal Yöntemler
# 17    BLM303                            İşaret ve Sistemler
# 18    BLM305                             İşletim Sistemleri
# 19    BLM325                        Mikroişlemci Sistemleri
# 20    BLM307                        Yazılım Laboratuvarı I
# 21    BLM309                                        Staj II
# 23    BLM323                 Bilgi Güvenliği ve Kriptografi
# 24    BLM321              Robotlar için Matematik Temelleri
# 25    MUH403                          Araştırma Problemleri
# 26    MUH402                              Bitirme Çalışması
# 27    BLM401                              Bilgisayar Ağları
# 28    BLM405           İş Hayatı ve İş Güvenliğine Hazırlık
# 30    BLM417                       Programlanabilir Yapılar
# 31    BLM421                         Yazılım Proje Yönetimi
# 32    BLM449                Bilgisayarlı Görmenin Temelleri
# 33    BLM429                       Veri Madenciliğine Giriş
# 34    BLM441                              Mobil Programlama
# 35    MUH445                    Mühendisler için İstatistik
# 36    BLM451                     Derin Öğrenmenin Temelleri
# 37    BLM443  Doğal Dil İşleme ve Metin Madenciliğine Giriş
# 38    MUH413                         Gezgin Robotlara Giriş
# 39    BLM435                          Biyoinformatiğe Giriş
# 40    BLM411                            Bilgisayar Semineri
#
#                DERSİ VEREN ÖĞR. ELEMANI  Seçmeli mi?     SINIF
# 0                 Öğr. Gör. Melih Yiğit        False  1. Sınıf
# 1                  Öğr. Gör. Şiva Koçak        False  1. Sınıf
# 2                   Öğr. Gör. Ali SEZER        False  1. Sınıf
# 3       Prof. Dr. Jale Süngü Yılmazkaya        False  1. Sınıf
# 4          Doç. Dr. Yücel Türker Ulutaş        False  1. Sınıf
# 5              Prof. Dr. Selda Çalkavur        False  1. Sınıf
# 6                Öğr. Gör. Dr. Onur Gök        False  1. Sınıf
# 7     Dr. Öğr. Üyesi Mehmet Ali Altuncu        False  1. Sınıf
# 8                Öğr. Gör. Dr. Onur Gök        False  1. Sınıf
# 9            Arş. Gör. Dr. Gülcan Özkum        False  2. Sınıf
# 10       Dr. Öğr. Üyesi Hikmetcan Özcan        False  2. Sınıf
# 11                Prof. Dr. Suhap Şahin        False  2. Sınıf
# 12           Dr. Öğr. Üyesi Burak İnner        False  2. Sınıf
# 13    Dr. Öğr. Üyesi Fidan Kaya Gülağız        False  2. Sınıf
# 14                  Doç. Dr. Alev Mutlu        False  2. Sınıf
# 15    Dr. Öğr. Üyesi Fidan Kaya Gülağız        False  2. Sınıf
# 16           Doç. Dr. MİNE AYLİN BAYRAK        False  3. Sınıf
# 17                Prof. Dr. Adnan Kavak        False  3. Sınıf
# 18                Prof. Dr. Suhap Şahin        False  3. Sınıf
# 19    Doç. Dr. Meltem Kurt Pehlivanoğlu        False  3. Sınıf
# 20            Dr. Öğr. Üyesi Furkan Göz        False  3. Sınıf
# 21    Dr. Öğr. Üyesi Fidan Kaya Gülağız        False  3. Sınıf
# 23    Doç. Dr. Meltem Kurt Pehlivanoğlu         True  3. Sınıf
# 24           Dr. Öğr. Üyesi Burak İnner         True  3. Sınıf
# 25  Ders Veren Bölüm Öğretim Elemanları        False  4. Sınıf
# 26  Ders Veren Bölüm Öğretim Elemanları        False  4. Sınıf
# 27            Doç. Dr. Pınar Onay Durdu        False  4. Sınıf
# 28                Öğr. Gör. Resul Özkan        False  4. Sınıf
# 30    Dr. Öğr. Üyesi Mehmet Ali Altuncu         True  4. Sınıf
# 31            Doç. Dr. Pınar Onay Durdu         True  4. Sınıf
# 32               Doç. Dr. Orhan Akbulut         True  4. Sınıf
# 33        Prof. Dr. Sevinç İlhan Omurca         True  4. Sınıf
# 34                Öğr. Gör. Uğur Yıldız         True  4. Sınıf
# 35               Doç. Dr. Orhan Akbulut         True  4. Sınıf
# 36       Dr. Öğr. Üyesi Burcu Kır Savaş         True  4. Sınıf
# 37            Dr. Öğr. Üyesi Furkan Göz         True  4. Sınıf
# 38           Dr. Öğr. Üyesi Burak İnner         True  4. Sınıf
# 39                  Doç. Dr. Alev Mutlu         True  4. Sınıf
# 40          Arş. Gör. Dr. Ayşe Gül Eker         True  4. Sınıf

# %%
def read_data(DATA_PATH):
    if DATA_PATH.endswith('.csv'):
        return pd.read_csv(DATA_PATH)
    elif DATA_PATH.endswith('.xlsx'):
        return pd.read_excel(DATA_PATH)
    else:
        raise ValueError("Unsupported file format")

# %%
ögrenci_list_df = read_data(OGRENCI_LISTESI_PATH)
print(ögrenci_list_df)
# Out:
#       Öğrenci No       Ad Soyad     Sınıf    Ders
# 0      210059017  Cansu Bozkurt  5. Sınıf  BLM401
# 1      210059017  Cansu Bozkurt  5. Sınıf  BLM405
# 2      210059017  Cansu Bozkurt  5. Sınıf  BLM411
# 3      210059017  Cansu Bozkurt  5. Sınıf  BLM417
# 4      210059017  Cansu Bozkurt  5. Sınıf  BLM421
# ...          ...            ...       ...     ...
# 3895   259757258     Nil Öztürk  1. Sınıf  FEF111
# 3896   259757258     Nil Öztürk  1. Sınıf  FEF113
# 3897   259757258     Nil Öztürk  1. Sınıf  FEF115
# 3898   259757258     Nil Öztürk  1. Sınıf  TDB107
# 3899   259757258     Nil Öztürk  1. Sınıf  YDB117
#
# [3900 rows x 4 columns]

# %%
ögrenci_list_df
# Out:
#       Öğrenci No       Ad Soyad     Sınıf    Ders
# 0      210059017  Cansu Bozkurt  5. Sınıf  BLM401
# 1      210059017  Cansu Bozkurt  5. Sınıf  BLM405
# 2      210059017  Cansu Bozkurt  5. Sınıf  BLM411
# 3      210059017  Cansu Bozkurt  5. Sınıf  BLM417
# 4      210059017  Cansu Bozkurt  5. Sınıf  BLM421
# ...          ...            ...       ...     ...
# 3895   259757258     Nil Öztürk  1. Sınıf  FEF111
# 3896   259757258     Nil Öztürk  1. Sınıf  FEF113
# 3897   259757258     Nil Öztürk  1. Sınıf  FEF115
# 3898   259757258     Nil Öztürk  1. Sınıf  TDB107
# 3899   259757258     Nil Öztürk  1. Sınıf  YDB117
#
# [3900 rows x 4 columns]
